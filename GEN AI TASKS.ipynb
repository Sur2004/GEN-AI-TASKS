# %% [markdown]
# # Task 1

# %%
#Problem 1
scores = [520, 780, 430] 
fr=scores[1]
if (scores[1]==scores[2]) or (scores[0]==scores[2]) or (scores[0]==scores[1]):
    print('Tie detected')
else:
    for i in range(len(scores)):
        for j in range(i,len(scores)):
            if scores[i]>scores[j]:
                scores[i],scores[j]=scores[j],scores[i]
    print("First rank:",scores[2])
    print("Second rank:",scores[1])
    print("Third rank:",scores[0])
# Out:
# First rank: 780
# Second rank: 520
# Third rank: 430

# %%
orders = [ "Veg", "Paneer", "Veg", "Cheese", "Paneer", "Veg" ]
s=set(orders)
print(len(s))
for i in s:
    print(i)
# Out:
# 3
# Cheese
# Veg
# Paneer

# %%
balance = 15000 
withdraw = 7000 
if withdraw <0:
    print("Invalid Amount")
if withdraw < balance:
    print("Withdrawl Completed")
    balance-=withdraw
    print('Balance:',balance)
elif withdraw > balance:
    print("Insufficient balance")
# Out:
# Withdrawl Completed
# Balance: 8000

# %%
marks = [96, 81, 55, 74, 67, 92]

for i in range(len(marks)):
    print("Student", i + 1, "- Marks:", marks[i], end=" -> ")

    if marks[i] >= 90:
        print("Full Scholarship")
    elif marks[i] >= 75:
        print("Half Scholarship")
    elif marks[i] >= 60:
        print("Training Program")
    else:
        print("Better Luck Next Time")
# Out:
# Student 1 - Marks: 96 -> Full Scholarship
# Student 2 - Marks: 81 -> Half Scholarship
# Student 3 - Marks: 55 -> Better Luck Next Time
# Student 4 - Marks: 74 -> Training Program
# Student 5 - Marks: 67 -> Training Program
# Student 6 - Marks: 92 -> Full Scholarship

# %%
# Problem 5
print("Problem 5")
signal = "Green"
if signal == "Red":
    print("STOP")
elif signal == "Yellow":
    print("READY")
elif signal == "Green":
    print("GO")
else:
    print("Signal Error")

print()

# Problem 6
print("Problem 6")
prices = [250,180,450,120,600]
total = 0
highest = prices[0]
lowest = prices[0]
for i in prices:
    total += i
    if i > highest:
        highest = i
    if i < lowest:
        lowest = i
print("Total Bill:", total)
print("Highest Price:", highest)
print("Lowest Price:", lowest)

print()

# Problem 7
print("Problem 7")
cases = [(16,True),(18,True),(25,False),(30,True)]
for age,ticket in cases:
    if age >= 18 and ticket:
        print("Entry Allowed")
    else:
        print("Entry Denied")

print()

# Problem 8
print("Problem 8")
books = ["Python","Java","Python","C","C++","Java"]
unique = set(books)
print(unique)
print(len(unique))
print("Python" in books)

print()

# Problem 9
print("Problem 9")
players = ["Ajay","Ravi","Ali","Kiran","John"]
for i in players:
    if i == "Ali":
        continue
    print(i)

print()

# Problem 10
print("Problem 10")
passengers = []
for i in range(1,101):
    passengers.append(i)
    if len(passengers) == 40:
        print("Bus Full")
        break

print()

# Problem 11
print("Problem 11")
numbers = [12,8,21,15,9,18,27]
for i in numbers:
    if i % 3 == 0 and i % 7 == 0:
        print(i)
        break

print()

# Problem 12
print("Problem 12")
fruits = ["Apple","Banana","Mango","Orange","Apple","Mango"]
if "Mango" in fruits:
    print("Available")
else:
    print("Out of Stock")
print(set(fruits))

print()

# Problem 13
print("Problem 13")
secret = 25
guesses = [10,14,25,31,42]
for i in guesses:
    if i == secret:
        print("Correct Guess")
        break

print()

# Problem 14
print("Problem 14")
patients = ["Rahul","Emergency","Sita","Ramesh","Akash"]
for i in patients:
    if i == "Emergency":
        print("Treat Immediately")
        break
    print(i)

print()

# Problem 15
print("Problem 15")
scores = [45,82,61,93,55,78]
count = 0
for i in scores:
    if i >= 60:
        print(i, "Qualified")
        count += 1
    else:
        print(i, "Not Qualified")
print("Total Qualified:", count)

print()

# Problem 16
print("Problem 16")
correct = 1234
entered = 1111
if entered == correct:
    print("Phone Unlocked")
else:
    print("Wrong Password")

print()

# Problem 17
print("Problem 17")
fare = 850
if fare > 1000:
    final = fare - fare * 20 / 100
elif fare > 500:
    final = fare - fare * 10 / 100
else:
    final = fare
print("Final Fare:", final)

print()

# Problem 18
print("Problem 18")
attendance = ["Present","Absent","Present","Present","Absent"]
present = 0
absent = 0
for i in attendance:
    if i == "Present":
        present += 1
    else:
        absent += 1
print("Present:", present)
print("Absent:", absent)

print()

# Problem 19
print("Problem 19")
countries = ["India","USA","India","Japan","Germany","USA","France"]
unique = set(countries)
print(unique)
print(len(unique))

print()

# Problem 20
print("Problem 20")
systems = ("Engine","Fuel","Navigation","Communication","Cooling")
status = ["OK","OK","FAIL","OK","OK"]
for i in range(len(systems)):
    if status[i] == "FAIL":
        print(systems[i])
        print("Launch Aborted!")
        break
else:
    print("Ready for Launch")
# Out:
# Problem 5
# GO
#
# Problem 6
# Total Bill: 1600
# Highest Price: 600
# Lowest Price: 120
#
# Problem 7
# Entry Denied
# Entry Allowed
# Entry Denied
# Entry Allowed
#
# Problem 8
# {'Python', 'Java', 'C++', 'C'}
# 4
# True
#
# Problem 9
# Ajay
# Ravi
# Kiran
# John
#
# Problem 10
# Bus Full
#
# Problem 11
# 21
#
# Problem 12
# Available
# {'Banana', 'Orange', 'Mango', 'Apple'}
#
# Problem 13
# Correct Guess
#
# Problem 14
# Rahul
# Treat Immediately
#
# Problem 15
# 45 Not Qualified
# 82 Qualified
# 61 Qualified
# 93 Qualified
# 55 Not Qualified
# 78 Qualified
# Total Qualified: 4
#
# Problem 16
# Wrong Password
#
# Problem 17
# Final Fare: 765.0
#
# Problem 18
# Present: 3
# Absent: 2
#
# Problem 19
# {'Japan', 'India', 'USA', 'France', 'Germany'}
# 5
#
# Problem 20
# Navigation
# Launch Aborted!

# %% [markdown]
# # TASK 2

# %%
print("Problem 1")
students={"Rahul":91,"Ayesha":84,"Kiran":67,"Ali":45}
p=f=0
for k,v in students.items():
    print(k,v,"Pass" if v>=40 else "Fail")
    if v>=40:p+=1
    else:f+=1
print("Passed:",p)
print("Failed:",f)

print("\nProblem 2")
inventory={"Rice":20,"Sugar":15,"Milk":8,"Eggs":30}
item="Milk"
if item in inventory:
    inventory[item]-=1
else:
    print("Item Not Available")
print(inventory)

print("\nProblem 3")
users={"admin":"python123","student":"welcome","guest":"guest123"}
a=0
while a<3:
    u=input("Username: ")
    p=input("Password: ")
    if u in users and users[u]==p:
        print("Login Successful")
        break
    a+=1
else:
    print("Account Locked")

print("\nProblem 4")
books={101:"Python",102:"Java",103:"SQL",104:"Machine Learning"}
try:
    x=int(input("Book ID: "))
    print(books[x] if x in books else "Book Not Found")
except:
    print("Invalid Input")

print("\nProblem 5")
cust={"Rahul":5000,"Ali":7000,"John":3500}
n=input("Customer: ")
print(cust[n] if n in cust else "Customer Not Found")

print("\nProblem 6")
exp={}
while True:
    n=input("Expense: ")
    if n=="stop":
        break
    exp[n]=float(input("Amount: "))
print(exp)
print(len(exp))

print("\nProblem 7")
with open("attendance.txt","w") as f:
    f.write("Rahul\nAyesha\nAli\nKiran")
with open("attendance.txt","r") as f:
    print(f.read())

print("\nProblem 8")
t=input("Today's Experience: ")
with open("diary.txt","w") as f:
    f.write(t)
print("Diary Saved Successfully")

print("\nProblem 9")
try:
    with open("marks.txt","r") as f:
        print(f.read())
except:
    print("File Not Found")

print("\nProblem 10")
try:
    a=float(input("First: "))
    b=float(input("Second: "))
    print(a/b)
except ZeroDivisionError:
    print("Division by Zero")
except ValueError:
    print("Invalid Number")

print("\nProblem 11")
scores={"Rahul":120,"Ali":250,"John":180}
name=""
high=-1hy
for k,v in scores.items():
    if v>high:
        high=v
        name=k
print(name,high)

print("\nProblem 12")
patients={101:"Rahul",102:"Sita",103:"Kiran",104:"Ali"}
try:
    x=int(input("ID: "))
    print(patients[x])
except:
    print("Invalid ID")

print("\nProblem 13")
seats={"A1":"Available","A2":"Booked","A3":"Available","A4":"Available"}
s=input("Seat: ")
if s.lower() in seats:
    if seats[s]=="Available":
        seats[s]="Booked"
        print("Booked")
    else:
        print("Seat Already Booked")

print("\nProblem 14")
t=input("Temperature: ")
with open("weather.txt","a") as f:
    f.write(t+"\n")

print("\nProblem 15")
items={"Milk":50,"Bread":40,"Eggs":70,"Rice":500}
bill=0
while True:
    x=input("Item: ")
    if x=="done":
        break
    if x in items:
        bill+=items[x]
print("Bill:",bill)

print("\nProblem 16")
fare={"Hyderabad":300,"Warangal":700,"Karimnagar":600}
c=input("City: ")
print(fare[c] if c in fare else "Service Not Available")

print("\nProblem 17")
while True:
    p=input("Password: ")
    if len(p)>=8:
        print("Password Accepted")
        break

print("\nProblem 18")
with open("text.txt","w") as f:
    f.write("Python is easy to learn")
with open("text.txt","r") as f:
    print(len(f.suryread().split()))

print("\nProblem 19")
d={"Name":"Rahul","Age":20,"Course":"CSE","City":"Hyderabad"}
print(d.keys())
print(d.values())
print(d.items())
d.update({"City":"Warangal"})
print(d)

print("\nProblem 20")
systems={"Engine":"OK","Fuel":"OK","Navigation":"FAIL","Communication":"OK"}
for k,v in systems.items():
    if v=="FAIL":
        print(k)
        with open("mission_log.txt","w") as f:
            f.write(k+" FAIL\nMission Aborted")
        print("Mission Aborted")
        break
else:
    with open("mission_log.txt","w") as f:
        f.write("Launch Successful")
# Out:
# Problem 1
# Rahul 91 Pass
# Ayesha 84 Pass
# Kiran 67 Pass
# Ali 45 Pass
# Passed: 4
# Failed: 0
#
# Problem 2
# {'Rice': 20, 'Sugar': 15, 'Milk': 7, 'Eggs': 30}
#
# Problem 3
# Username:  surya
# Password:  surya2123
# Username:  teesh
# Password:  teja213
# Username:  bhagi
# Password:  bhagi234
# Account Locked
#
# Problem 4
# Book ID:  5
# Book Not Found
#
# Problem 5
# Customer:  surya
# Customer Not Found
#
# Problem 6
# Expense:  500
# Amount:  2000
# Expense:  300
# Amount:  3000
# Expense:  stop
# {'500': 2000.0, '300': 3000.0}
# 2
#
# Problem 7
# Rahul
# Ayesha
# Ali
# Kiran
#
# Problem 8
# Today's Experience:  very good
# Diary Saved Successfully
#
# Problem 9
# File Not Found
#
# Problem 10
# First:  4
# Second:  0
# Division by Zero
#
# Problem 11
# Ali 250
#
# Problem 12
# ID:  2
# Invalid ID
#
# Problem 13
# Seat:  a1
# Problem 14
# Temperature:  40
# Problem 15
# Item:  bread
# Item:  milk
# Item:  jam
# Item:  book
# Item:  light
# Item:  goods
# Item:  fruits
# ...

# %% [markdown]
# # TASK-3

# %%
print('Problem 1')
students={"Rahul":91,"Ayesha":84,"Kiran":67,"Ali":45}
p=f=0
for k,v in students.items():
    s="Pass" if v>=40 else "Fail"
    print(k,v,s)
    if v>=40:p+=1
    else:f+=1
print("Passed:",p)
print("Failed:",f)

print("\nProblem 2")
inventory={"Rice":20,"Sugar":15,"Milk":8,"Eggs":30}
if "Milk" in inventory:
    inventory["Milk"]-=1
print(inventory)

print("\nProblem 5")
cust={"Rahul":5000,"Ali":7000,"John":3500}
print(cust["Rahul"])

print("\nProblem 7")
open("attendance.txt","w").write("Rahul\nAyesha\nAli\nKiran")
print(open("attendance.txt").read())

print("\nProblem 9")
try:
    print(open("marks.txt").read())
except:
    print("File Not Found")

print("\nProblem 11")
scores={"Rahul":120,"Ali":250,"John":180}
name=""
high=-1
for k,v in scores.items():
    if v>high:
        high=v
        name=k
print(name,high)

print("\nProblem 18")
open("text.txt","w").write("Python is easy to learn")
print(len(open("text.txt").read().split()))

print("\nProblem 19")
d={"Name":"Rahul","Age":20,"Course":"CSE","City":"Hyderabad"}
print(d)
d.update({"City":"Warangal"})
print(d)

print("\nProblem 20")
systems={"Engine":"OK","Fuel":"OK","Navigation":"FAIL","Communication":"OK"}
for k,v in systems.items():
    if v=="FAIL":
        print(k)
        print("Mission Aborted")
        break
# Out:
# Problem 1
# Rahul 91 Pass
# Ayesha 84 Pass
# Kiran 67 Pass
# Ali 45 Pass
# Passed: 4
# Failed: 0
#
# Problem 2
# {'Rice': 20, 'Sugar': 15, 'Milk': 7, 'Eggs': 30}
#
# Problem 5
# 5000
#
# Problem 7
# Rahul
# Ayesha
# Ali
# Kiran
#
# Problem 9
# File Not Found
#
# Problem 11
# Ali 250
#
# Problem 18
# 5
#
# Problem 19
# {'Name': 'Rahul', 'Age': 20, 'Course': 'CSE', 'City': 'Hyderabad'}
# {'Name': 'Rahul', 'Age': 20, 'Course': 'CSE', 'City': 'Warangal'}
#
# Problem 20
# Navigation
# Mission Aborted

# %% [markdown]
# # TASK-4

# %%
import mysql.connector as my
if my:
    print("true")
# Out:
# true

# %%
import mysql.connector
 
dataBase = mysql.connector.connect(
  host ="localhost",              
  user ="root",
  passwd ="root"
)

# %%
cursor = dataBase.cursor()
cursor.execute("use classicmodels")

# %%
# Problem 1
print("\nProblem 1")
query = """
SELECT employeeNumber, firstName, lastName,
50000 AS Salary,
5000 AS Bonus,
55000 AS TotalSalary
FROM employees;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 2
print("\nProblem 2")
query = """
SELECT productName, buyPrice,
buyPrice + 500 AS NewBuyPrice
FROM products;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 3
print("\nProblem 3")
query = """
SELECT productName, buyPrice, MSRP,
MSRP - buyPrice AS EstimatedProfit
FROM products;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 4
print("\nProblem 4")
query = """
SELECT *
FROM products
WHERE buyPrice > 50;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 5
print("\nProblem 5")
query = """
SELECT *
FROM orderdetails
WHERE quantityOrdered >= 40;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 6
print("\nProblem 6")
query = """
SELECT *
FROM customers
WHERE country = 'USA';
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 7
print("\nProblem 7")
query = """
SELECT *
FROM customers
WHERE country = 'USA'
OR country = 'France';
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 8
print("\nProblem 8")
query = """
SELECT *
FROM orderdetails
WHERE quantityOrdered > 30
AND priceEach > 100;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 9
print("\nProblem 9")
query = """
SELECT *
FROM customers
WHERE country <> 'USA';
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 10
print("\nProblem 10")
query = """
SELECT *
FROM customers
WHERE country IN ('USA','France','Germany');
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 11
print("\nProblem 11")
query = """
SELECT *
FROM products
WHERE productLine IN ('Classic Cars','Motorcycles','Planes');
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 12
print("\nProblem 12")
query = """
SELECT *
FROM employees
WHERE officeCode IN (1,4,7);
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 13
print("\nProblem 13")
query = """
SELECT *
FROM products
WHERE buyPrice BETWEEN 30 AND 80;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 14
print("\nProblem 14")
query = """
SELECT *
FROM orderdetails
WHERE quantityOrdered BETWEEN 20 AND 50;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 15
print("\nProblem 15")
query = """
SELECT *
FROM offices
WHERE officeCode BETWEEN 2 AND 5;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 16
print("\nProblem 16")
query = """
SELECT *
FROM customers
WHERE customerName LIKE 'A%';
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 17
print("\nProblem 17")
query = """
SELECT *
FROM products
WHERE productName LIKE '%Ford%';
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 18
print("\nProblem 18")
query = """
SELECT *
FROM customers
WHERE country LIKE '%land';
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 19
print("\nProblem 19")
query = """
SELECT *
FROM products
WHERE productName LIKE '1969%';
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 20
print("\nProblem 20")
query = """
SELECT *
FROM employees
WHERE firstName LIKE 'L%';
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 21
print("\nProblem 21")
query = """
SELECT *
FROM customers
WHERE customerName LIKE 'A____';
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

cursor.close()
dataBase.close()
print("\nConnection Closed Successfully")
# Out:
# Problem 1
# (1002, 'Diane', 'Murphy', 50000, 5000, 55000)
# (1056, 'Mary', 'Patterson', 50000, 5000, 55000)
# (1076, 'Jeff', 'Firrelli', 50000, 5000, 55000)
# (1088, 'William', 'Patterson', 50000, 5000, 55000)
# (1102, 'Gerard', 'Bondur', 50000, 5000, 55000)
# (1143, 'Anthony', 'Bow', 50000, 5000, 55000)
# (1165, 'Leslie', 'Jennings', 50000, 5000, 55000)
# (1166, 'Leslie', 'Thompson', 50000, 5000, 55000)
# (1188, 'Julie', 'Firrelli', 50000, 5000, 55000)
# (1216, 'Steve', 'Patterson', 50000, 5000, 55000)
# (1286, 'Foon Yue', 'Tseng', 50000, 5000, 55000)
# (1323, 'George', 'Vanauf', 50000, 5000, 55000)
# (1337, 'Loui', 'Bondur', 50000, 5000, 55000)
# (1370, 'Gerard', 'Hernandez', 50000, 5000, 55000)
# (1401, 'Pamela', 'Castillo', 50000, 5000, 55000)
# (1501, 'Larry', 'Bott', 50000, 5000, 55000)
# (1504, 'Barry', 'Jones', 50000, 5000, 55000)
# (1611, 'Andy', 'Fixter', 50000, 5000, 55000)
# (1612, 'Peter', 'Marsh', 50000, 5000, 55000)
# (1619, 'Tom', 'King', 50000, 5000, 55000)
# ...

# %% [markdown]
# # TASK-5

# %%
import mysql.connector
 
dataBase = mysql.connector.connect(
  host ="localhost",              
  user ="root",
  passwd ="root"
)

cursor = dataBase.cursor()
cursor.execute("use classicmodels")


# Problem 1
print("\nProblem 1")
query = """
SELECT SUM(amount) AS TotalSales
FROM payments;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 2
print("\nProblem 2")
query = """
SELECT COUNT(*) AS TotalCustomers,
MAX(creditLimit) AS HighestCredit,
MIN(creditLimit) AS LowestCredit,
AVG(creditLimit) AS AverageCredit
FROM customers;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 3
print("\nProblem 3")
query = """
SELECT MAX(buyPrice) AS HighestBuyPrice,
MIN(buyPrice) AS LowestBuyPrice,
AVG(buyPrice) AS AverageBuyPrice
FROM products;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 4
print("\nProblem 4")
query = """
SELECT country,
COUNT(*) AS TotalCustomers
FROM customers
GROUP BY country;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 5
print("\nProblem 5")
query = """
SELECT officeCode,
COUNT(*) AS TotalEmployees
FROM employees
GROUP BY officeCode;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 6
print("\nProblem 6")
query = """
SELECT productLine,
COUNT(*) AS TotalProducts
FROM products
GROUP BY productLine;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 7
print("\nProblem 7")
query = """
SELECT *
FROM customers
ORDER BY creditLimit DESC;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 8
print("\nProblem 8")
query = """
SELECT *
FROM products
ORDER BY buyPrice ASC;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 9
print("\nProblem 9")
query = """
SELECT *
FROM employees
ORDER BY firstName,lastName;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 10
print("\nProblem 10")
query = """
SELECT *
FROM customers
ORDER BY creditLimit DESC
LIMIT 5;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 11
print("\nProblem 11")
query = """
SELECT *
FROM products
ORDER BY buyPrice ASC
LIMIT 10;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 12
print("\nProblem 12")
query = """
SELECT *
FROM orders
ORDER BY orderNumber DESC
LIMIT 7;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)
# Problem 13
print("\nProblem 13")
query = """
SELECT country, COUNT(*) AS TotalCustomers
FROM customers
GROUP BY country
HAVING COUNT(*) > 5;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 14
print("\nProblem 14")
query = """
SELECT productLine, COUNT(*) AS TotalProducts
FROM products
GROUP BY productLine
HAVING COUNT(*) > 10;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 15
print("\nProblem 15")
query = """
SELECT officeCode, COUNT(*) AS TotalEmployees
FROM employees
GROUP BY officeCode
HAVING COUNT(*) > 2;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 16
print("\nProblem 16")
query = """
SELECT customerName, orderNumber, orderDate
FROM customers
INNER JOIN orders
ON customers.customerNumber = orders.customerNumber;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 17
print("\nProblem 17")
query = """
SELECT CONCAT(firstName,' ',lastName) AS EmployeeName,
city,
country
FROM employees
INNER JOIN offices
ON employees.officeCode = offices.officeCode;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 18
print("\nProblem 18")
query = """
SELECT customerName, orderNumber
FROM customers
LEFT JOIN orders
ON customers.customerNumber = orders.customerNumber;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 19
print("\nProblem 19")
query = """
SELECT CONCAT(firstName,' ',lastName) AS EmployeeName,
customerName
FROM employees
LEFT JOIN customers
ON employees.employeeNumber = customers.salesRepEmployeeNumber;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 20
print("\nProblem 20")
query = """
SELECT city,
CONCAT(firstName,' ',lastName) AS EmployeeName
FROM employees
RIGHT JOIN offices
ON employees.officeCode = offices.officeCode;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 21
print("\nProblem 21")
query = """
SELECT customerName, orderNumber
FROM customers
LEFT JOIN orders
ON customers.customerNumber = orders.customerNumber

UNION

SELECT customerName, orderNumber
FROM customers
RIGHT JOIN orders
ON customers.customerNumber = orders.customerNumber;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

# Problem 22
print("\nProblem 22")
query = """
CREATE TABLE students1(
studentID INT PRIMARY KEY,
name VARCHAR(100) NOT NULL,
email VARCHAR(100) UNIQUE,
age INT CHECK(age>=18)
);
"""
cursor.execute(query)
print("Table students created.")

# Problem 23
print("\nProblem 23")
query = """
CREATE TABLE course1(
courseID INT PRIMARY KEY,
courseName VARCHAR(100) UNIQUE,
duration VARCHAR(50) NOT NULL
);
"""
cursor.execute(query)
print("Table courses created.")

# Problem 24
print("\nProblem 24")
query = """
CREATE TABLE enrollment1(
studentID INT,
courseID INT,
enrollmentDate DATE,
PRIMARY KEY(studentID,courseID),
FOREIGN KEY(studentID) REFERENCES students(studentID),
FOREIGN KEY(courseID) REFERENCES courses(courseID)
);
"""
cursor.execute(query)
print("Table enrollments created.")

dataBase.commit()

# ---------------- MINI CHALLENGE ----------------

print("\nMini Challenge 1")
query = """
SELECT *
FROM customers
ORDER BY creditLimit DESC
LIMIT 5;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

print("\nMini Challenge 2")
query = """
SELECT country, COUNT(*) AS TotalCustomers
FROM customers
GROUP BY country;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

print("\nMini Challenge 3")
query = """
SELECT productLine, COUNT(*) AS TotalProducts
FROM products
GROUP BY productLine
HAVING COUNT(*) > 10;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

print("\nMini Challenge 4")
query = """
SELECT customerName, orderNumber
FROM customers
INNER JOIN orders
ON customers.customerNumber = orders.customerNumber;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

print("\nMini Challenge 5")
query = """
SELECT CONCAT(firstName,' ',lastName) AS EmployeeName,
city
FROM employees
INNER JOIN offices
ON employees.officeCode = offices.officeCode;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

print("\nMini Challenge 6")
query = """
SELECT AVG(buyPrice)
FROM products;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

print("\nMini Challenge 7")
query = """
SELECT MAX(amount)
FROM payments;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

print("\nMini Challenge 8")
query = """
SELECT COUNT(*)
FROM products;
"""
cursor.execute(query)
for row in cursor.fetchall():
    print(row)

cursor.close()
dataBase.close()

print("\nConnection Closed Successfully")
# Out:
# Problem 1
# (Decimal('8853839.23'),)
#
# Problem 2
# (122, Decimal('227600.00'), Decimal('0.00'), Decimal('67659.016393'))
#
# Problem 3
# (Decimal('103.42'), Decimal('15.91'), Decimal('54.395182'))
#
# Problem 4
# ('France', 12)
# ('USA', 36)
# ('Australia', 5)
# ('Norway', 1)
# ('Poland', 1)
# ('Germany', 13)
# ('Spain', 7)
# ('Sweden', 2)
# ('Denmark', 2)
# ('Singapore', 3)
# ('Norway  ', 2)
# ('Portugal', 2)
# ('Japan', 2)
# ('Finland', 3)
# ('UK', 5)
# ('Ireland', 2)
# ('Canada', 3)
# ('Hong Kong', 1)
# ('Italy', 4)
# ('Switzerland', 3)
# ('Netherlands', 1)
# ('Belgium', 2)
# ('New Zealand', 4)
# ('South Africa', 1)
# ('Austria', 2)
# ('Philippines', 1)
# ('Russia', 1)
# ('Israel', 1)
#
# Problem 5
# ('1', 6)
# ('2', 2)
# ('3', 2)
# ('4', 5)
# ('5', 2)
# ('6', 4)
# ('7', 2)
#
# Problem 6
# ('Classic Cars', 38)
# ('Motorcycles', 13)
# ('Planes', 12)
# ('Ships', 9)
# ('Trains', 3)
# ('Trucks and Buses', 11)
# ('Vintage Cars', 24)
#
# Problem 7
# ...
